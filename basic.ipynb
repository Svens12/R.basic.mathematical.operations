# %%
print("Hello R Program")
# Out:
# [1] "Hello R Program"

# %%
x<-18

# %%
y<-4

# %%
z<-x+y

# %%
z
# Out:
# [1] 22

# %%
18+4
# Out:
# [1] 22

# %%
18-4
# Out:
# [1] 14

# %%
10/2
# Out:
# [1] 5

# %%
4.5/2
# Out:
# [1] 2.25

# %%
2**3
# Out:
# [1] 8

# %%
9**.5
# Out:
# [1] 3

# %%
14%%4
# Out:
# [1] 2

# %%
10%%3.5
# Out:
# [1] 3

# %%
8%/%3
# Out:
# [1] 2

# %%
TRUE+TRUE
# Out:
# [1] 2

# %%
TRUE+FALSE
# Out:
# [1] 1
